# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd
import requests
from geopy.distance import geodesic

# %%
# Connection DB
connectionDB = 'mysql+pymysql://ironhack_user:%Vq=c>G5@173.201.189.217/BiciMAD'
engineDB = create_engine(connectionDB)
inspector_db = inspect(engineDB)

# %%
# Tables DB
inspector_db.get_table_names()
# Out:
# ['bicimad_stations', 'bicipark_stations']

# %%
query_1 = '''
SELECT *
FROM bicimad_stations

'''
df_1 = pd.read_sql_query(query_1, engineDB)
df_1
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
#base_url = https://datos.madrid.es/egob #base del endpoint v1:version 1
#parameneter = '/4F4pp8NUW08JuXwnoxglpN'
#related = '/related-artists'
#track = '/top-tracks'
#resource = '/artists'   # un parámetro
#header = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
colum = df_1['geometry.coordinates']

# %%
print(type(colum))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_1[["longitude","latitude"]]=df_1["geometry.coordinates"].str.split(",",expand=True)
df_1['longitude'] = df_1['longitude'].str.replace('[','',regex=True)
df_1["latitude"]=df_1['latitude'].str.replace(']','',regex=True)
df_1['latitude'] = pd.to_numeric(df_1['latitude'])
df_1['longitude'] = pd.to_numeric(df_1['longitude'])
df_1
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_1['distance'] = pd.to_numeric(df_1['longitude'])
df_1

# %%
df_1[['geometry.coordinates']]
# Out:
#                         geometry.coordinates
# 0                   [-3.7018341, 40.4172137]
# 1    [-3.701602938060457, 40.41731271011562]
# 2                   [-3.7058415, 40.4205886]
# 3                   [-3.7069171, 40.4302937]
# 4                   [-3.7025875, 40.4285524]
# ..                                       ...
# 259                     [-3.72997, 40.43896]
# 260                     [-3.72699, 40.44375]
# 261                     [-3.72693, 40.44342]
# 262                 [-3.7272945, 40.4483322]
# 263                     [-3.72937, 40.45109]
#
# [264 rows x 1 columns]

# %%
#response = requests.get('https://datos.madrid.es/egob/catalogo/200761-0-parques-jardines.json')
#json = response.json()
#json.keys()

# %%
#df_1_csv = pd.read_csv('/Users/FVILLALOBOS/Ironhack//Data/bicimad_stations_202207111929.csv')
#df_1_csv

# %%
query_2 = '''
SELECT * 
FROM bicipark_stations
'''
df_2 = pd.read_sql_query(query_1, engineDB)
df_2
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
df_2[["longitude","latitude"]]=df_2["geometry.coordinates"].str.split(",",expand=True)
df_2['longitude'] = df_2['longitude'].str.replace('[','',regex=True)
df_2["latitude"]=df_2['latitude'].str.replace(']','',regex=True)
df_2['latitude'] = pd.to_numeric(df_2['latitude'])
df_2['longitude'] = pd.to_numeric(df_2['longitude'])
df_2
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...

# %%
#df_2_csv = pd.read_csv('/Users/FVILLALOBOS/Ironhack//Data/bicipark_stations_202207111930.csv')
#df_2_csv
